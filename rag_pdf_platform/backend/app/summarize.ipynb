# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
import os 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Retrieve the stored variables
# %store -r texts
# %store -r tables

# %%
## add switch case for prompts for different use case 
# Prompt
prompt_text = """
You are an assistant tasked with summarizing tables and text.
Give a concise summary of the table or text.

Respond only with the summary, no additionnal comment.
Do not start your message by saying "Here is a summary" or anything like that.
Just give the summary as it is.

Table or text chunk: {element}

"""
prompt = ChatPromptTemplate.from_template(prompt_text)

# Summary chain
model = ChatGroq(temperature=0.5, model="llama-3.1-8b-instant")
summarize_chain = {"element": lambda x: x} | prompt | model | StrOutputParser()

# %%
# Summarize text
text_summaries = summarize_chain.batch(texts, {"max_concurrency": 1})

# Summarize tables
tables_html = [table.metadata.text_as_html for table in tables]
table_summaries = summarize_chain.batch(tables_html, {"max_concurrency": 1})

# %%
text_summaries
# Out:
# ['The paper "Attention Is All You Need" proposes a new neural network architecture called the Transformer, which uses only attention mechanisms and eliminates recurrence and convolutions. The Transformer outperforms existing models in machine translation tasks, achieving a 28.4 BLEU score on the English-to-German task and a 41.8 BLEU score on the English-to-French task, while requiring less training time and being more parallelizable.',
#  'Recurrent neural networks, specifically long short-term memory and gated recurrent neural networks, have been established as state of the art in sequence modeling and transduction problems. However, sequential computation limits parallelization and memory constraints. Recent work has achieved improvements in efficiency and performance through factorization tricks and conditional computation, but the fundamental constraint of sequential computation remains.',
#  'The Transformer model architecture consists of an encoder-decoder structure with stacked self-attention and point-wise, fully connected layers. The encoder has 6 identical layers with two sub-layers each: multi-head self-attention and position-wise feed-forward networks, followed by residual connections and layer normalization. The decoder has 6 identical layers with three sub-layers: two similar to the encoder and a third for multi-head attention over the encoder output, also with residual connections and layer normalization.',
#  'The attention function maps a query and key-value pairs to an output, computing a weighted sum of the values based on a compatibility function of the query with the keys. The scaled dot-product attention algorithm multiplies the dot products of the query with the keys by 1/√dk, applies a softmax function, and divides each by the values.',
#  'Multi-head attention linearly projects queries, keys, and values h times with different projections, then performs attention in parallel, yielding dv-dimensional output values. These are concatenated and projected to final values. Multi-head attention allows the model to jointly attend to information from different representation subspaces at different positions, with h = 8 parallel attention layers used in this work.',
#  'The transformer model uses a fully connected feed-forward network (FFN) in each layer, consisting of two linear transformations with a ReLU activation in between, to process input sequences. The FFN is applied separately to each position in the sequence. The model also uses learned embeddings to convert input tokens and output tokens to vectors, and shares weight matrices between embedding layers and the pre-softmax linear transformation. Positional encodings are added to input embeddings to make use of the order of the sequence, using sine and cosine functions of different frequencies.',
#  'Self-attention layers are compared to recurrent and convolutional layers for sequence transduction tasks. They have lower computational complexity per layer, allow more parallelization, and shorter path lengths between long-range dependencies, making them more suitable for tasks like machine translation.',
#  'The training regime for the models involved training on large datasets, using Adam optimizer, and applying three types of regularization: Residual Dropout, Label Smoothing, and possibly another type (not specified). The base models were trained for 12 hours, while the big models were trained for 3.5 days, using 8 NVIDIA P100 GPUs.',
#  "The Transformer model outperforms previous models on WMT 2014 English-to-German and English-to-French translation tasks, achieving state-of-the-art BLEU scores of 28.4 and 41.0 respectively. The model's training cost is significantly lower than its competitors, and varying the model's components shows that bigger models are better and dropout is helpful in avoiding over-fitting.",
#  'The Transformer model was tested on English constituency parsing and achieved state-of-the-art results, outperforming previous models with the exception of the Recurrent Neural Network Grammar.',
#  'The paper presents the Transformer, a sequence transduction model based on attention, which achieves state-of-the-art results in translation tasks and can be trained significantly faster than architectures based on recurrent or convolutional layers.',
#  'This is a list of research papers in the fields of natural language processing and computer vision, including topics such as language models, neural machine translation, and deep learning architectures.',
#  'The attention mechanism in a neural network model is visualized, showing how different attention heads attend to specific parts of a sentence to resolve dependencies and exhibit behavior related to sentence structure.']
